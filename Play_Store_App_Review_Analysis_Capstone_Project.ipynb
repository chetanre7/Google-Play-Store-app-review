# %% [markdown]
# <a href="https://colab.research.google.com/github/chetanre7/Google-Play-Store-app-review/blob/main/Play_Store_App_Review_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Play Store apps data has enormous potential to drive app-making businesses to success. Actionable insights can be drawn for developers to work on and capture the Android market. </b>
#
# ## <b> Each app (row) has values for catergory, rating, size, and more. Another dataset contains customer reviews of the android apps.</b>
#
# ## <b> Explore and analyze the data to discover key factors responsible for app engagement and success. </b>

# %% [markdown]
# #**Google Play Store Apps Exploratory Data Analysis**
#
# ---

# %% [markdown]
# #*Data Preparation and Cleaning*
# In this section, we will be loading the Google Store Apps data stored in csv using pandas which is a fast and powerful python library for data analysis and easy data manipulation in pandas DataFrame object. It is usually used for working with tabular data (e.g data in spreadsheet) in various formats such as CSV, Excel spreadsheets, HTML tables, JSON etc. We will then perform some data preparation and also cleaning on it.

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Mounting Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#loading the file of play store data
google_play_df=pd.read_csv('/content/drive/MyDrive/Play Store Data.csv')

# %%
google_play_df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
user_reviews_df=pd.read_csv('/content/drive/MyDrive/User Reviews.csv')

# %%
user_reviews_df.head(5)
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
google_play_df.columns # name of each column in play store file  (13 columns)
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
user_reviews_df.columns # name of each column in user reviews  store file  (5 columns)
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
google_play_df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
google_play_df.boxplot();

# %%
google_play_df.hist();

# %% [markdown]
# As per the Boxplot and Histogram we see that there is an outlier so we have to remove that outlier

# %% [markdown]
# #Data Cleaning

# %%
google_play_df.info()     #This gives us details about column and Non Null cell and remaining Null cell
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
google_play_df.isnull().sum()     # This will gives us total null values present in each column
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ##Checking the outliers

# %%
google_play_df[google_play_df.Rating > 5]   # I got row number 10472 as an outlier because of rating 19
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
google_play_df.drop([10472],inplace= True)                # drop will remove the romove the row which contain outlier
google_play_df[10471:10474]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
#
#           Installs  Type Price Content Rating           Genres  \
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
#
#             Last Updated Current Ver   Android Ver
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# 10473     August 7, 2018     6.06.14    4.4 and up
# 10474  November 21, 2014     2.2.1.5    2.2 and up

# %%
google_play_df.boxplot();

# %%
google_play_df.hist();

# %% [markdown]
# #Data Manipulation

# %%
google_play_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# Here, we realized that there are 1474 rows having null values under column 'Rating'.
# Hence, we decided to replace the null values with median of overall 'Rating' values.

# %%
def replace_with_median(series):
    """
    Given a series, replace the rows with null values 
    with median values
    """
    return series.fillna(series.median())

google_play_df['Rating'] = google_play_df['Rating'].transform(replace_with_median)
google_play_df['Rating'] = google_play_df['Rating'].astype(float)

# %%
google_play_df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       2
# dtype: int64

# %% [markdown]
# Now i have null values in column Type, Current Ver and Android Ver.
#
# I am going to replace null values of above 3 columns with mode of that perticular column.

# %%
print(google_play_df['Type'].mode())    
print(google_play_df['Current Ver'].mode())   
print(google_play_df['Android Ver'].mode())
# Out:
# 0    Free
# dtype: object
# 0    Varies with device
# dtype: object
# 0    4.1 and up
# dtype: object

# %%
google_play_df['Type'].fillna(str(google_play_df['Type'].mode().values[0]),inplace=True)
google_play_df['Current Ver'].fillna(str(google_play_df['Current Ver'].mode().values[0]),inplace=True)
google_play_df['Android Ver'].fillna(str(google_play_df['Android Ver'].mode().values[0]),inplace=True)

# %%
google_play_df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# In this way we removed all the null values that are present in the data

# %% [markdown]
# ##**Exploratory Analysis and Visualization**

# %% [markdown]
# Count vs sentiments Graph for userreview

# %%
plt.figure(figsize=(7,5))
sns.set(font_scale=1)
sns.countplot(x = "Sentiment",data = user_reviews_df)
plt.show()

# %% [markdown]
# As we can see from the graph people with positive sentiments tend to give more feedback as compared to neutral and negative sentiments. Positive sentiments indicating user satisfaction with the product provided by the developer or the administrato

# %% [markdown]
# ##Displot showing ratings criteria with mean and median

# %%
x = google_play_df.Type.value_counts()
mylabel= ['Free','Paid']
plt.pie(x,labels=mylabel,autopct= "%1.1f%%")
plt.show()

# %% [markdown]
# As we can see from the upper pie chart is that free applications consist of a major portion of Google Play store. Paid applications are significantly less as compared to free applications. We can also conclude that developers are most dependent on post-business instead of pre-business taking money up front.

# %% [markdown]
# **The top 20 apps present in the google play store as per their Genres**

# %%
# get the number of apps for each category
sns.set_style('darkgrid')
plt.figure(figsize=(10, 5))
sns.countplot(x='Category', data=google_play_df)
plt.title('Number of Apps Per Category')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# From the above plotting we know that most of the apps in the play store are from the categories of 'Family', 'Game' and also 'Tools.

# %% [markdown]
# ###**Rating**

# %%
# the distribution of rating
plt.figure(figsize=(10, 5))
sns.countplot(x='Rating', data=google_play_df)
plt.title('Rating Distribution')
plt.xticks(rotation=90)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# From this distribution plotting, it implies that most of the apps in the Play Store are having rating higher than 4 or in the range of 4 to 4.7.
# We conclude that the median of the rating is 4.3.

# %%
# The distribution of apps in term of their rating, size and type
plt.figure(figsize=(12, 6))
sns.scatterplot(google_play_df['Size'],
               google_play_df['Rating'],
               hue=google_play_df['Type'],
               s=50);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From the above scatter plot, we can imply that majority of the free apps are small in size and having high rating. While for paid apps, we have quite equal distribution in term on size and rating.
